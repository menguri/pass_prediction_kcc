# %%
import os, sys
from tqdm import tqdm
sys.path.append(os.path.abspath(os.path.dirname(os.getcwd())))

import numpy as np
import pandas as pd
import ast
import matplotlib.pyplot as plt

from src.features import intended_receiver, extract_player_pos, extract_pass
from src.visualization import plot_action
from src.preprocess_data import make_freeze_frame
from src.labels import get_intended_receiver

# this is very useful as it makes sure that always all columns and rows of a data frame are displayed
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
match1 = pd.read_csv('../metrica-data/preprocess-data/tracking-data/match1.csv')
match2 = pd.read_csv('../metrica-data/preprocess-data/tracking-data/match2.csv')
match3 = pd.read_csv('../metrica-data/preprocess-data/tracking-data/match3.csv')
all_events = pd.read_csv('../metrica-data/EPV-data/labelling-all-match.csv')
all_events['freeze_frame'] = all_events['freeze_frame'].apply(ast.literal_eval)
# all_events['Intended_Receiver'] = all_events['Baseline Intended_Receiver'].apply(ast.literal_eval)

# %%
len(all_events)
# Out:
# 7300

# %%
all_events['eventName'].value_counts()
# Out:
# eventName
# Pass              3314
# CARRY             1395
# CHALLENGE          879
# RECOVERY           820
# BALL LOST          372
# SET PIECE          247
# BALL OUT           140
# SHOT                68
# FAULT RECEIVED      54
# CARD                11
# Name: count, dtype: int64

# %% [markdown]
# #### Dribble 라벨링

# %%
carry_event = all_events[all_events['eventName']=='CARRY']

# %%
len(carry_event)
# Out:
# 1395

# %%
carry_event = all_events[all_events['eventName']=='CARRY'][['eventName', 'start_frame', 'end_frame', 'from', 'event_id', 'game_id']].reset_index(drop=True)

accurate = []
for idx, row in carry_event.iterrows():
    #event로 알아내기
    df_carry = all_events[(all_events['start_frame'] >= row['start_frame'])
                             &(all_events['start_frame'] <= row['end_frame'])
                             &(all_events['game_id'] == row['game_id'])]
    event_list = list(df_carry['eventName'].values)
    event_list_num = [1 for event in event_list if event in ["BALL LOST", "BALL OUT"]]
    if sum(event_list_num) >= 1:
            accurate.append("fail")
    else:
            accurate.append("success")

carry_event['result'] = accurate
carry_event.head()
# Out:
#   eventName  start_frame  end_frame from  event_id  game_id   result
# 0     CARRY          377        384  A07      3682        3  success
# 1     CARRY          426        465  A08      3684        3  success
# 2     CARRY          507        530  A02      3686        3  success
# 3     CARRY          580        598  A03      3688        3  success
# 4     CARRY          628        652  A04      3690        3  success

# %%
carry_event['result'].value_counts()
# Out:
# result
# success    1179
# fail        216
# Name: count, dtype: int64

# %% [markdown]
# #### Shot 라벨링

# %%
shot_event = all_events[all_events['eventName']=='SHOT']

# %%
shot_event[(shot_event['goal']==1)&(shot_event['ownGoal']==1)]
# Out:
# Empty DataFrame
# Columns: [team, type, subtype, session, start_frame, start_time, end_frame, end_time, from, to, start_x, start_y, end_x, end_y, phase, goal, ownGoal, teamId, eventName, freeze_frame, accurate, value_label, Baseline Intended-Receiver, game_id, event_id, True Intended-receiver, no pass]
# Index: []

# %%
shot_event = all_events[all_events['eventName']=='SHOT']
shot_event['result'] = shot_event['goal']
shot_event['result'] =  shot_event['result'].replace({0:'fail', 1:'success'})
shot_event.head()
# Out:
# C:\Users\M207\AppData\Local\Temp\ipykernel_4608\1563230451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_event['result'] = shot_event['goal']
# C:\Users\M207\AppData\Local\Temp\ipykernel_4608\1563230451.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shot_event['result'] =  shot_event['result'].replace({0:'fail', 1:'success'})
#      team  type              subtype  session  start_frame  start_time  \
# 34   Home  SHOT  HEAD-ON TARGET-GOAL        1         2289       91.56
# 79   Home  SHOT       OFF TARGET-OUT        1         5923      236.92
# 110  Away  SHOT       OFF TARGET-OUT        1         7753      310.12
# 135  Home  SHOT      ON TARGET-SAVED        1         9628      385.12
# 239  Home  SHOT  HEAD-OFF TARGET-OUT        1        18270      730.80
#
#      end_frame  end_time from   to  start_x  start_y   end_x  end_y  phase  \
# 34        2309     92.36  A09  NaN    99.36    33.84  109.08  39.60      1
# 79        5953    238.12  A10  NaN    90.72    19.44  112.32  43.20      1
# 110       7789    311.56  B21  NaN    21.60    21.60   -4.32  46.80      1
# 135       9632    385.28  A08  NaN   103.68    26.64  105.84  33.12      1
# 239      18301    732.04  A08  NaN   101.52    39.60  111.24  43.92      1
#
#      goal  ownGoal  teamId eventName  \
# 34      1        0       1      SHOT
# 79      0        0       1      SHOT
# 110     0        0       2      SHOT
# 135     0        0       1      SHOT
# 239     0        0       1      SHOT
#
#                                           freeze_frame  accurate  value_label  \
# 34   {'A11': {'teammate': True, 'actor': False, 'ba...       NaN            0
# 79   {'A11': {'teammate': True, 'actor': False, 'ba...       NaN            0
# 110  {'B25': {'teammate': True, 'actor': False, 'ba...       NaN            0
# 135  {'A11': {'teammate': True, 'actor': False, 'ba...       NaN            0
# 239  {'A11': {'teammate': True, 'actor': False, 'ba...       NaN            0
#
#     Baseline Intended-Receiver  game_id  event_id True Intended-receiver  \
# 34                          {}        1        34                    NaN
# 79                          {}        1        79                    NaN
# 110                         {}        1       110                    NaN
# 135                         {}        1       135                    NaN
# 239                         {}        1       239                    NaN
#
#      no pass   result
# 34       NaN  success
# 79       NaN     fail
# 110      NaN     fail
# 135      NaN     fail
# 239      NaN     fail

# %% [markdown]
# #### Cross 라벨링

# %% [markdown]
# - Cross / Cross-Interception 모두 Cross를 지칭한다. (영상을 통해 확인 완료)
# - eventName에 Pass로 분류되어 있으며, accurate도 들어가있다.

# %%
all_events.loc[all_events['subtype'].str.contains('CROSS'), 'eventName'] = 'CROSS'

# %%
cross_event = all_events[all_events['eventName']=='CROSS']
cross_event['result'] = cross_event['accurate']
cross_event['result'] =  cross_event['result'].replace({0:'fail', 1:'success'})
cross_event.head()
# Out:
# C:\Users\M207\AppData\Local\Temp\ipykernel_4608\51931812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cross_event['result'] = cross_event['accurate']
# C:\Users\M207\AppData\Local\Temp\ipykernel_4608\51931812.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cross_event['result'] =  cross_event['result'].replace({0:'fail', 1:'success'})
#      team       type             subtype  session  start_frame  start_time  \
# 33   Home       PASS               CROSS        1         2263       90.52
# 89   Away  BALL LOST  CROSS-INTERCEPTION        1         6987      279.48
# 162  Away  BALL LOST  CROSS-INTERCEPTION        1        11987      479.48
# 393  Away  BALL LOST  CROSS-INTERCEPTION        1        29016     1160.64
# 459  Away  BALL LOST  CROSS-INTERCEPTION        1        34619     1384.76
#
#      end_frame  end_time from   to  start_x  start_y  end_x  end_y  phase  \
# 33        2289     91.56  A10  A09    96.12    10.08  99.36  33.84      1
# 89        7043    281.72  B22  NaN    41.04    60.48   8.64  28.80      1
# 162      12032    481.28  B18  NaN    23.76     8.64   3.24  43.92      1
# 393      29061   1162.44  B21  NaN    17.28    69.12   9.72  31.68      1
# 459      34644   1385.76  B21  NaN     7.56    59.04   4.32  40.32      1
#
#      goal  ownGoal  teamId eventName  \
# 33      0        0       1     CROSS
# 89      0        0       2     CROSS
# 162     0        0       2     CROSS
# 393     0        0       2     CROSS
# 459     0        0       2     CROSS
#
#                                           freeze_frame  accurate  value_label  \
# 33   {'A11': {'teammate': True, 'actor': False, 'ba...       1.0            1
# 89   {'B25': {'teammate': True, 'actor': False, 'ba...       0.0            0
# 162  {'B25': {'teammate': True, 'actor': False, 'ba...       0.0            0
# 393  {'B25': {'teammate': True, 'actor': False, 'ba...       0.0            0
# 459  {'B25': {'teammate': True, 'actor': False, 'ba...       0.0            0
#
#                             Baseline Intended-Receiver  game_id  event_id  \
# 33   {'dist': {'ID': 'A09', 'end_x': 98.46468, 'end...        1        33
# 89   {'dist': {'ID': 'B24', 'end_x': 29.20644, 'end...        1        89
# 162  {'dist': {'ID': 'B23', 'end_x': 15.55524, 'end...        1       162
# 393  {'dist': {'ID': 'B24', 'end_x': 15.13404, 'end...        1       393
# 459  {'dist': {'ID': 'B24', 'end_x': 9.828, 'end_y'...        1       459
#
#     True Intended-receiver  no pass   result
# 33                     NaN      NaN  success
# 89                     B23      NaN     fail
# 162                    B23      NaN     fail
# 393                    B24      NaN     fail
# 459                    B24      NaN     fail

# %%
len(cross_event)
# Out:
# 43

# %%
cross_event['subtype'].value_counts()
# Out:
# subtype
# CROSS-INTERCEPTION    22
# CROSS                 21
# Name: count, dtype: int64

# %%
cross_event['accurate'].value_counts()
# Out:
# accurate
# 0.0    31
# 1.0    12
# Name: count, dtype: int64

# %% [markdown]
# #### 패스 라벨링

# %%
# get all passes
pass_event = all_events[
                (all_events["eventName"] == "Pass")
                & (all_events["start_frame"] < all_events["end_frame"])
            ].copy()
pass_event['result'] = pass_event['accurate']
pass_event['result'] =  pass_event['result'].replace({0:'fail', 1:'success'})
pass_event.head()
# Out:
#    team  type subtype  session  start_frame  start_time  end_frame  end_time  \
# 1  Away  PASS    PASS        1            1        0.04          3      0.12
# 2  Away  PASS    PASS        1            3        0.12         17      0.68
# 3  Away  PASS    PASS        1           45        1.80         61      2.44
# 4  Away  PASS    PASS        1           77        3.08         96      3.84
# 5  Away  PASS    PASS        1          191        7.64        217      8.68
#
#   from   to  start_x  start_y  end_x  end_y  phase  goal  ownGoal  teamId  \
# 1  B19  B21     48.6    28.08  59.40  30.96      1     0        0       2
# 2  B21  B15     59.4    30.96  62.64  15.12      1     0        0       2
# 3  B15  B19     59.4    13.68  48.60  22.32      1     0        0       2
# 4  B19  B21     48.6    23.04  52.92  33.84      1     0        0       2
# 5  B21  B22     43.2    52.56  34.56  70.56      1     0        0       2
#
#   eventName                                       freeze_frame  accurate  \
# 1      Pass  {'B25': {'teammate': True, 'actor': False, 'ba...       1.0
# 2      Pass  {'B25': {'teammate': True, 'actor': False, 'ba...       1.0
# 3      Pass  {'B25': {'teammate': True, 'actor': False, 'ba...       1.0
# 4      Pass  {'B25': {'teammate': True, 'actor': False, 'ba...       1.0
# 5      Pass  {'B25': {'teammate': True, 'actor': False, 'ba...       1.0
#
#    value_label                         Baseline Intended-Receiver  game_id  \
# 1            0  {'dist': {'ID': 'B21', 'end_x': 59.66244, 'end...        1
# 2            0  {'dist': {'ID': 'B15', 'end_x': 63.06444, 'end...        1
# 3            0  {'dist': {'ID': 'B19', 'end_x': 48.33756, 'end...        1
# 4            0  {'dist': {'ID': 'B21', 'end_x': 52.67376, 'end...        1
# 5            0  {'dist': {'ID': 'B22', 'end_x': 33.16356, 'end...        1
#
#    event_id True Intended-receiver  no pass   result
# 1         1                    NaN      NaN  success
# 2         2                    NaN      NaN  success
# 3         3                    NaN      NaN  success
# 4         4                    NaN      NaN  success
# 5         5                    NaN      NaN  success

# %%
pass_event['accurate'].value_counts()
# Out:
# accurate
# 1.0    2870
# 0.0     381
# Name: count, dtype: int64

# %%
pass_event['result'].value_counts()
# Out:
# result
# success    2870
# fail        381
# Name: count, dtype: int64

# %% [markdown]
# #### 최종 통합

# %%
all_events_final = all_events.copy()
pass_carry_shot = pd.concat([pass_event, carry_event, shot_event, cross_event], axis=0)

# %%
pass_carry_shot['result'].value_counts()
# Out:
# result
# success    4069
# fail        688
# Name: count, dtype: int64

# %%
pass_carry_shot['eventName'].value_counts()
# Out:
# eventName
# Pass     3251
# CARRY    1395
# SHOT       68
# CROSS      43
# Name: count, dtype: int64

# %%
all_events_f = pd.merge(all_events_final, pass_carry_shot[['event_id', 'result']], how='left', on='event_id')

# %%
all_events_f.head()
# Out:
#    team       type   subtype  session  start_frame  start_time  end_frame  \
# 0  Away  SET PIECE  KICK OFF        1            1        0.04          0
# 1  Away       PASS      PASS        1            1        0.04          3
# 2  Away       PASS      PASS        1            3        0.12         17
# 3  Away       PASS      PASS        1           45        1.80         61
# 4  Away       PASS      PASS        1           77        3.08         96
#
#    end_time from   to  start_x  start_y  end_x  end_y  phase  goal  ownGoal  \
# 0      0.00  B19  NaN      NaN      NaN    NaN    NaN      1     0        0
# 1      0.12  B19  B21     48.6    28.08  59.40  30.96      1     0        0
# 2      0.68  B21  B15     59.4    30.96  62.64  15.12      1     0        0
# 3      2.44  B15  B19     59.4    13.68  48.60  22.32      1     0        0
# 4      3.84  B19  B21     48.6    23.04  52.92  33.84      1     0        0
#
#    teamId  eventName                                       freeze_frame  \
# 0       2  SET PIECE                                                 {}
# 1       2       Pass  {'B25': {'teammate': True, 'actor': False, 'ba...
# 2       2       Pass  {'B25': {'teammate': True, 'actor': False, 'ba...
# 3       2       Pass  {'B25': {'teammate': True, 'actor': False, 'ba...
# 4       2       Pass  {'B25': {'teammate': True, 'actor': False, 'ba...
#
#    accurate  value_label                         Baseline Intended-Receiver  \
# 0       NaN            0                                                 {}
# 1       1.0            0  {'dist': {'ID': 'B21', 'end_x': 59.66244, 'end...
# 2       1.0            0  {'dist': {'ID': 'B15', 'end_x': 63.06444, 'end...
# 3       1.0            0  {'dist': {'ID': 'B19', 'end_x': 48.33756, 'end...
# 4       1.0            0  {'dist': {'ID': 'B21', 'end_x': 52.67376, 'end...
#
#    game_id  event_id True Intended-receiver  no pass   result
# 0        1         0                    NaN      NaN      NaN
# 1        1         1                    NaN      NaN  success
# 2        1         2                    NaN      NaN  success
# 3        1         3                    NaN      NaN  success
# 4        1         4                    NaN      NaN  success

# %%
all_events_f['eventName'].value_counts()
# Out:
# eventName
# Pass              3271
# CARRY             1395
# CHALLENGE          879
# RECOVERY           820
# BALL LOST          372
# SET PIECE          247
# BALL OUT           140
# SHOT                68
# FAULT RECEIVED      54
# CROSS               43
# CARD                11
# Name: count, dtype: int64

# %%
len(all_events_f)
# Out:
# 7300

# %%
all_events_f.to_csv('all_events_final.csv')
